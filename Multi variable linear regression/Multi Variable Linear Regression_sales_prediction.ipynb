# %% [markdown]
# # Multi Variable Linear Regression

# %%
cd "F:\Knowledge\ML\courses_ML\Content\My_codes\ML_Core\Multi variable linear regression"
# Out:
# F:\Knowledge\ML\courses_ML\Content\My_codes\ML_Core\Multi variable linear regression

# %% [markdown]
# # Step 1: Importing Libraries

# %%
#pip install seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import skew
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# # Step 2: Load the Data

# %% [markdown]
# The adverstiting dataset captures sales revenue generated with respect to advertisement spends across multiple channles like radio, tv and newspaper.

# %%
advert = pd.read_csv('Advertising.csv')
advert.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
advert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# # Step 3: Plot Data

# %%
sns.pairplot(advert, x_vars=['TV','radio','newspaper'], y_vars='sales', height=7, aspect=0.7)

# %% [markdown]
# # Step 4: Estimating Coefficients

# %%
from sklearn.linear_model import LinearRegression

# create X and y
feature_cols = ['TV', 'radio', 'newspaper']
X = advert[feature_cols]
y = advert.sales

# instantiate and fit
lr = LinearRegression()
lr.fit(X, y)

# print the coefficients
print(lr.intercept_)
print(lr.coef_)
# Out:
# 2.938889369459412
# [ 0.04576465  0.18853002 -0.00103749]

# %%
# pair the feature names with the coefficients
list(zip(feature_cols, lr.coef_))
# Out:
# [('TV', 0.0457646454553976),
#  ('radio', 0.18853001691820442),
#  ('newspaper', -0.0010374930424763285)]

# %%
sns.heatmap(advert.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Step 5:  Prediction & Model Evaluation

# %%
from sklearn.metrics import mean_squared_error
y_pred = lr.predict(X[['TV', 'radio', 'newspaper']])
print(lr.score(X, y))
print(mean_squared_error(y, y_pred))
# Out:
# 0.8972106381789522
# 2.784126314510936
